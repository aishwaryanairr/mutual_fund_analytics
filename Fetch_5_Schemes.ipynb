# %%
import requests
import pandas as pd

schemes = {
    "SBI_Bluechip":119551,
    "ICICI_Bluechip":120503,
    "Nippon_Large_Cap":118632,
    "Axis_Bluechip":119092,
    "Kotak_Bluechip":120841
}

for scheme, code in schemes.items():

    url = f"https://api.mfapi.in/mf/{code}"

    response = requests.get(url)

    data = response.json()

    df = pd.DataFrame(data["data"])

    df.to_csv(
        f"data/raw/{scheme}.csv",
        index=False
    )

    print(f"Saved {scheme}")
# Out:
# Saved SBI_Bluechip
# Saved ICICI_Bluechip
# Saved Nippon_Large_Cap
# Saved Axis_Bluechip
# Saved Kotak_Bluechip
